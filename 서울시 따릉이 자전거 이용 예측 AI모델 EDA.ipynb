# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_data = pd.read_csv('train.csv')
train_data
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 0        3    20                  16.3                     1.0
# 1        6    13                  20.1                     0.0
# 2        7     6                  13.9                     0.0
# 3        8    23                   8.1                     0.0
# 4        9    18                  29.5                     0.0
# ...    ...   ...                   ...                     ...
# 1454  2174     4                  16.8                     0.0
# 1455  2175     3                  10.8                     0.0
# 1456  2176     5                  18.3                     0.0
# 1457  2178    21                  20.7                     0.0
# 1458  2179    17                  21.1                     0.0
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 0                    1.5               89.0                576.0
# 1                    1.4               48.0                916.0
# ...

# %%
train_data.isnull().sum()
# Out:
# id                          0
# hour                        0
# hour_bef_temperature        2
# hour_bef_precipitation      2
# hour_bef_windspeed          9
# hour_bef_humidity           2
# hour_bef_visibility         2
# hour_bef_ozone             76
# hour_bef_pm10              90
# hour_bef_pm2.5            117
# count                       0
# dtype: int64

# %%
train_data.fillna(0, inplace = True)

# %%
colormap = plt.cm.gist_heat
plt.figure(figsize = (15, 12))
sns.heatmap(train_data.corr(), linewidths = 0.1, vmax = 0.5, cmap = colormap, linecolor = 'white', annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(vars = ['hour', 'hour_bef_temperature', 'hour_bef_precipitation', 'hour_bef_windspeed', 'hour_bef_humidity', 'count'], data = train_data)
plt.show()

# %%
sns.pairplot(vars = ['hour_bef_visibility', 'hour_bef_ozone', 'hour_bef_pm10', 'hour_bef_pm2.5', 'count'], data = train_data)
plt.show()

# %%
sns.countplot(train_data['hour_bef_precipitation'])
plt.show()
# Out:
# C:\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(x = 'hour', data = train_data,)
plt.show()

# %%
sns.boxplot(x = 'hour_bef_temperature', data = train_data)
plt.show()

# %%
sns.boxplot(x = 'hour_bef_windspeed', data = train_data)
plt.show()

# %%
sns.boxplot(x = 'hour_bef_visibility', data = train_data)
plt.show()

# %%
sns.boxplot(x = 'hour_bef_ozone', data = train_data)
plt.show()
